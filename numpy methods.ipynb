# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.DataFrame(np.random.randn((200)), columns=['data'])

# %%
df
# Out:
#          data
# 0    0.048578
# 1    0.776120
# 2    1.205305
# 3    0.780973
# 4   -1.041026
# ..        ...
# 195 -0.979612
# 196 -0.441610
# 197 -2.025925
# 198 -1.484774
# 199 -1.061032
#
# [200 rows x 1 columns]

# %%
df.plot(figsize= (40,10))
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
df= pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (15,25))
# Out:
# <AxesSubplot:>

# %%
df.drop('petal_width' , axis=1)
# Out:
#      sepal_length  sepal_width  petal_length    species
# 0             5.1          3.5           1.4     setosa
# 1             4.9          3.0           1.4     setosa
# 2             4.7          3.2           1.3     setosa
# 3             4.6          3.1           1.5     setosa
# 4             5.0          3.6           1.4     setosa
# ..            ...          ...           ...        ...
# 145           6.7          3.0           5.2  virginica
# 146           6.3          2.5           5.0  virginica
# 147           6.5          3.0           5.2  virginica
# 148           6.2          3.4           5.4  virginica
# 149           5.9          3.0           5.1  virginica
#
# [150 rows x 4 columns]

# %%
df1 = df.drop('petal_width' , axis=1)

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df2=df1.head(20)

# %% [markdown]
# df2

# %%
df2
# Out:
#     sepal_length  sepal_width  petal_length species
# 0            5.1          3.5           1.4  setosa
# 1            4.9          3.0           1.4  setosa
# 2            4.7          3.2           1.3  setosa
# 3            4.6          3.1           1.5  setosa
# 4            5.0          3.6           1.4  setosa
# 5            5.4          3.9           1.7  setosa
# 6            4.6          3.4           1.4  setosa
# 7            5.0          3.4           1.5  setosa
# 8            4.4          2.9           1.4  setosa
# 9            4.9          3.1           1.5  setosa
# 10           5.4          3.7           1.5  setosa
# 11           4.8          3.4           1.6  setosa
# 12           4.8          3.0           1.4  setosa
# 13           4.3          3.0           1.1  setosa
# 14           5.8          4.0           1.2  setosa
# 15           5.7          4.4           1.5  setosa
# 16           5.4          3.9           1.3  setosa
# ...

# %%
df2.plot(kind='bar', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df2.iloc[2:8].plot(kind='bar', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df2.drop('species', axis=1)
# Out:
#     sepal_length  sepal_width  petal_length
# 0            5.1          3.5           1.4
# 1            4.9          3.0           1.4
# 2            4.7          3.2           1.3
# 3            4.6          3.1           1.5
# 4            5.0          3.6           1.4
# 5            5.4          3.9           1.7
# 6            4.6          3.4           1.4
# 7            5.0          3.4           1.5
# 8            4.4          2.9           1.4
# 9            4.9          3.1           1.5
# 10           5.4          3.7           1.5
# 11           4.8          3.4           1.6
# 12           4.8          3.0           1.4
# 13           4.3          3.0           1.1
# 14           5.8          4.0           1.2
# 15           5.7          4.4           1.5
# 16           5.4          3.9           1.3
# 17           5.1          3.5           1.4
# 18           5.7          3.8           1.7
# 19           5.1          3.8           1.5

# %%
df.iloc[[2]].plot(kind='barh', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np
df= pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
df.plot.scatter(x='sepal_length', y='petal_length', c= 'sepal_width', s=df['petal_width']*200)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length', y='petal_length', gridsize= 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
 df1=df.drop(columns='species').iloc[0]

# %%
df1.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import cufflinks as cf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6584\189640202.py in <module>
# ----> 1 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
# !pip install cufflinks
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 81.7/81.7 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68718 sha256=8b3334376497c4d2ae2d5785b9627a30c620502aadbfd60256fd3d7da7f27973
#   Stored in directory: c:\users\adars\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.head(10).iplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8808\3146594387.py in <module>
# ----> 1 df.head(10).iplot()
#
# NameError: name 'df' is not defined

# %%
df.iplot(x='sepal_length',y='petal_length')
# Out:
# <div>                            <div id="a1b570e5-4e0e-4404-ad5f-7c4a027ba8ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="scatter",mode="markers", size=5)
# Out:
# <div>                            <div id="f0c5ca97-f5eb-4315-9a46-a23b16bca1ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter3d', x='sepal_length',y='petal_length',z='petal_width')
# Out:
# <div>                            <div id="0c17a4db-543d-4cf8-8fed-f55a388e37dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib 
df = pd.read_csv('https://gist.githubusercontent.com/bigsnarfdude/515849391ad37fe593997fe0db98afaa/raw/f663366d17b7d05de61a145bbce7b2b961b3b07f/weather.csv')

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df.drop(columns=('play')).iplot(kind='scatter',mode='markers')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8808\413517330.py in <module>
# ----> 1 df.drop(columns=('play')).iplot(kind='scatter',mode='markers')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
import seaborn as sns
df1=sns.load_dataset('tips')

# %% [markdown]
# df1

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',col='time',data=df1)

# %%
sns.relplot(x='total_bill',y='tip',col='size',data=df1,hue='smoker')

# %%
import seaborn as sns
df1=sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day',y='total_bill',data=df1, kind='box',hue='sex')
