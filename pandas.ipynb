# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F428-7914
#
#  Directory of C:\Users\adars
#
# 22-12-2022  12:39    <DIR>          .
# 22-12-2022  12:39    <DIR>          ..
# 29-11-2022  18:07    <DIR>          .android
# 22-12-2022  12:25    <DIR>          .ipynb_checkpoints
# 15-11-2022  10:56    <DIR>          .ipython
# 13-12-2022  11:24    <DIR>          .jupyter
# 14-11-2022  22:19    <DIR>          .ms-ad
# 07-12-2022  18:58             6,853 -1.14-windows.xml
# 10-12-2022  13:29    <DIR>          3D Objects
# 13-07-2022  21:14    <DIR>          Contacts
# 14-12-2022  19:26    <DIR>          Desktop
# 12-12-2022  16:07    <DIR>          Documents
# 19-12-2022  17:31    <DIR>          Downloads
# 13-07-2022  21:14    <DIR>          Favorites
# 13-07-2022  21:14    <DIR>          Links
# 13-07-2022  21:14    <DIR>          Music
# 17-08-2022  22:48    <DIR>          OneDrive
# 22-12-2022  12:39               619 pandas.ipynb
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F428-7914
#
#  Directory of C:\Users\adars
#
# 22-12-2022  12:40    <DIR>          .
# 22-12-2022  12:40    <DIR>          ..
# 29-11-2022  18:07    <DIR>          .android
# 22-12-2022  12:25    <DIR>          .ipynb_checkpoints
# 15-11-2022  10:56    <DIR>          .ipython
# 13-12-2022  11:24    <DIR>          .jupyter
# 14-11-2022  22:19    <DIR>          .ms-ad
# 07-12-2022  18:58             6,853 -1.14-windows.xml
# 10-12-2022  13:29    <DIR>          3D Objects
# 13-07-2022  21:14    <DIR>          Contacts
# 14-12-2022  19:26    <DIR>          Desktop
# 12-12-2022  16:07    <DIR>          Documents
# 19-12-2022  17:31    <DIR>          Downloads
# 13-07-2022  21:14    <DIR>          Favorites
# 13-07-2022  21:14    <DIR>          Links
# 13-07-2022  21:14    <DIR>          Music
# 17-08-2022  22:48    <DIR>          OneDrive
# 22-12-2022  12:39               619 pandas.ipynb
# ...

# %%
pd.read_csv('sample_tax_rates.csv')
# Out:
#   Country Code State Code   ZIP/Postcode City  Rate % Tax Name  Priority  \
# 0           GB          *              *    *    20.0      VAT         1
# 1           GB          *              *    *     5.0      VAT         1
# 2           GB          *              *    *     0.0      VAT         1
# 3           US          *              *    *    10.0       US         1
# 4           US         AL  12345; 123456    *     2.0    US AL         2
#
#    Compound  Shipping     Tax Class
# 0         1         1           NaN
# 1         1         1  reduced-rate
# 2         1         1     zero-rate
# 3         1         1           NaN
# 4         1         1           NaN

# %%
pd.read_csv('sample_products.csv')
# Out:
#     ID                           Type                     SKU  \
# 0   44                       variable           woo-vneck-tee
# 1   45                       variable              woo-hoodie
# 2   46                         simple    woo-hoodie-with-logo
# 3   47                         simple              woo-tshirt
# 4   48                         simple              woo-beanie
# 5   58                         simple                woo-belt
# 6   60                         simple                 woo-cap
# 7   62                         simple          woo-sunglasses
# 8   64                         simple  woo-hoodie-with-pocket
# 9   66                         simple  woo-hoodie-with-zipper
# 10  68                         simple     woo-long-sleeve-tee
# 11  70                         simple                woo-polo
# 12  73  simple, downloadable, virtual               woo-album
# 13  75  simple, downloadable, virtual              woo-single
# ...

# %%
d = pd.read_csv('sample_products.csv')

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('sample_products.csv')
# Out:
#     ID                           Type                     SKU  \
# 0   44                       variable           woo-vneck-tee
# 1   45                       variable              woo-hoodie
# 2   46                         simple    woo-hoodie-with-logo
# 3   47                         simple              woo-tshirt
# 4   48                         simple              woo-beanie
# 5   58                         simple                woo-belt
# 6   60                         simple                 woo-cap
# 7   62                         simple          woo-sunglasses
# 8   64                         simple  woo-hoodie-with-pocket
# 9   66                         simple  woo-hoodie-with-zipper
# 10  68                         simple     woo-long-sleeve-tee
# 11  70                         simple                woo-polo
# 12  73  simple, downloadable, virtual               woo-album
# 13  75  simple, downloadable, virtual              woo-single
# ...

# %%
pd.read_csv('sample_products.csv',[compression=','])
# Out:
#   File "C:\Users\adars\AppData\Local\Temp\ipykernel_10988\2406991309.py", line 1
#     pd.read_csv('sample_products.csv',[compression=','])
#                                                   ^
# SyntaxError: invalid syntax

# %%
pd.read_csv('sample_products.csv',skiprows=[1-20])
# Out:
#     ID                           Type                     SKU  \
# 0   44                       variable           woo-vneck-tee
# 1   45                       variable              woo-hoodie
# 2   46                         simple    woo-hoodie-with-logo
# 3   47                         simple              woo-tshirt
# 4   48                         simple              woo-beanie
# 5   58                         simple                woo-belt
# 6   60                         simple                 woo-cap
# 7   62                         simple          woo-sunglasses
# 8   64                         simple  woo-hoodie-with-pocket
# 9   66                         simple  woo-hoodie-with-zipper
# 10  68                         simple     woo-long-sleeve-tee
# 11  70                         simple                woo-polo
# 12  73  simple, downloadable, virtual               woo-album
# 13  75  simple, downloadable, virtual              woo-single
# ...

# %%
d.dtypes
# Out:
# ID                            int64
# Type                         object
# SKU                          object
# Name                         object
# Published                     int64
# Is featured?                  int64
# Visibility in catalog        object
# Short description            object
# Description                  object
# Date sale price starts      float64
# Date sale price ends        float64
# Tax status                   object
# Tax class                   float64
# In stock?                     int64
# Stock                       float64
# Backorders allowed?           int64
# Sold individually?            int64
# Weight (lbs)                float64
# Length (in)                 float64
# Width (in)                  float64
# Height (in)                 float64
# Allow customer reviews?       int64
# Purchase note               float64
# Sale price                  float64
# Regular price               float64
# Categories                   object
# ...

# %%
d.head(2)
# Out:
#    ID      Type            SKU            Name  Published  Is featured?  \
# 0  44  variable  woo-vneck-tee  V-Neck T-Shirt          1             1
# 1  45  variable     woo-hoodie          Hoodie          1             0
#
#   Visibility in catalog            Short description  \
# 0               visible  This is a variable product.
# 1               visible  This is a variable product.
#
#                                          Description  Date sale price starts  \
# 0  Pellentesque habitant morbi tristique senectus...                     NaN
# 1  Pellentesque habitant morbi tristique senectus...                     NaN
#
#    ...  Attribute 1 global Attribute 2 name  Attribute 2 value(s)  \
# 0  ...                 1.0             Size  Large, Medium, Small
# 1  ...                 1.0             Logo               Yes, No
#
#    Attribute 2 visible  Attribute 2 global  Meta: _wpcom_is_markdown  \
# 0                  1.0                 1.0                       1.0
# ...

# %%
d.tail(5)
# Out:
#     ID       Type                   SKU                Name  Published  \
# 20  83     simple       Woo-tshirt-logo   T-Shirt with Logo          1
# 21  85     simple       Woo-beanie-logo    Beanie with Logo          1
# 22  87    grouped       logo-collection     Logo Collection          1
# 23  89   external            wp-pennant   WordPress Pennant          1
# 24  90  variation  woo-hoodie-blue-logo  Hoodie - Blue, Yes          1
#
#     Is featured? Visibility in catalog             Short description  \
# 20             0               visible     This is a simple product.
# 21             0               visible     This is a simple product.
# 22             0               visible    This is a grouped product.
# 23             0               visible  This is an external product.
# 24             0               visible                           NaN
#
#                                           Description  Date sale price starts  \
# ...

# %%
d.columns
# Out:
# Index(['ID', 'Type', 'SKU', 'Name', 'Published', 'Is featured?',
#        'Visibility in catalog', 'Short description', 'Description',
#        'Date sale price starts', 'Date sale price ends', 'Tax status',
#        'Tax class', 'In stock?', 'Stock', 'Backorders allowed?',
#        'Sold individually?', 'Weight (lbs)', 'Length (in)', 'Width (in)',
#        'Height (in)', 'Allow customer reviews?', 'Purchase note', 'Sale price',
#        'Regular price', 'Categories', 'Tags', 'Shipping class', 'Images',
#        'Download limit', 'Download expiry days', 'Parent', 'Grouped products',
#        'Upsells', 'Cross-sells', 'External URL', 'Button text', 'Position',
#        'Attribute 1 name', 'Attribute 1 value(s)', 'Attribute 1 visible',
#        'Attribute 1 global', 'Attribute 2 name', 'Attribute 2 value(s)',
#        'Attribute 2 visible', 'Attribute 2 global', 'Meta: _wpcom_is_markdown',
#        'Download 1 name', 'Download 1 URL', 'Download 2 name',
#        'Download 2 URL'],
# ...

# %%
d[['Type','SKU','Name']]
# Out:
#                              Type                     SKU  \
# 0                        variable           woo-vneck-tee
# 1                        variable              woo-hoodie
# 2                          simple    woo-hoodie-with-logo
# 3                          simple              woo-tshirt
# 4                          simple              woo-beanie
# 5                          simple                woo-belt
# 6                          simple                 woo-cap
# 7                          simple          woo-sunglasses
# 8                          simple  woo-hoodie-with-pocket
# 9                          simple  woo-hoodie-with-zipper
# 10                         simple     woo-long-sleeve-tee
# 11                         simple                woo-polo
# 12  simple, downloadable, virtual               woo-album
# 13  simple, downloadable, virtual              woo-single
# 14                      variation       woo-vneck-tee-red
# ...

# %%
pd.read_excel('newexcel.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
pd.read_excel('newexcel.xlsx',sheet_name="Create Portfolio")
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11132\2076984128.py in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_pdf('certificate.pdf')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'read_pdf'

# %%
import pandas as pd
d ="""{ "name" : "hell",
"studentid" : "3546464",
"subjects" : ["enlgish" , "hindi" , "marathi" , "scinec"]

}"""

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'hell',
#  'studentid': '3546464',
#  'subjects': ['enlgish', 'hindi', 'marathi', 'scinec']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#    name studentid subjects
# 0  hell   3546464  enlgish
# 1  hell   3546464    hindi
# 2  hell   3546464  marathi
# 3  hell   3546464   scinec

# %%
result['studentid']
# Out:
# '3546464'

# %%
pd.DataFrame(result['subjects'])
# Out:
#          0
# 0  enlgish
# 1    hindi
# 2  marathi
# 3   scinec

# %%
import json 
import pandas as pd

# %%
df = pd.read_html('https://opensource.adobe.com/Spry/samples/data_region/JSONDataSetSample.html')

# %%
pd.DataFrame(df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py:576: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
#                                                    0
# 0       id    type    name    image.width    imag...
# 1       id    type    name    image.width    imag...
# 2  Empty DataFrame
# Columns: [ds_RowID, id, type, ...
# 3         id    type    name
# 0  {id}  {type}  {name}
# 4  Empty DataFrame
# Columns: [ds_RowID, id, type, ...
# 5       id    type    name                 batter...
# 6  Empty DataFrame
# Columns: [ds_RowID, id, type, ...
# 7       id    type    name                 batter...
# 8                                                ...
# ...
